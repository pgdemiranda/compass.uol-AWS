# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# Para a solução, usar o argumento `usecols`

# %%
df = pd.read_csv("./etapa-1/concert_tours_by_women.csv")

# %%
df.columns
# Out:
# Index(['Rank', 'Peak', 'All Time Peak', 'Actual gross',
#        'Adjustedgross (in 2022 dollars)', 'Artist', 'Tour title', 'Year(s)',
#        'Shows', 'Average gross', 'Ref.'],
#       dtype='object')

# %%
columns = [
    'Rank', 
    'Actual gross', 
    'Adjustedgross (in 2022 dollars)', 
    'Artist', 
    'Tour title', 
    'Shows', 
    'Average gross', 
    'Year(s)'
]

df = df[columns]

# %% [markdown]
# devo usar set_index() para setar o Rank como índice? Ver o produto final, se no csv as linhas de index aparecer, vou precisar ver isso também.

# %%
df
# Out:
#     Rank     Actual gross Adjustedgross (in 2022 dollars)        Artist  \
# 0      1     $780,000,000                    $780,000,000  Taylor Swift
# 1      2     $579,800,000                    $579,800,000       Beyoncé
# 2      3     $411,000,000                    $560,622,615       Madonna
# 3      4     $397,300,000                    $454,751,555          Pink
# 4      5     $345,675,146                    $402,844,849  Taylor Swift
# 5      6     $305,158,363                    $388,978,496       Madonna
# 6      7     $280,000,000                    $381,932,682   Celine Dion
# 7      8     $257,600,000                    $257,600,000          Pink
# 8      9     $256,084,556                    $312,258,401       Beyoncé
# 9     10     $250,400,000                    $309,141,878  Taylor Swift
# 10    11  $229,100,000[b]                    $283,202,896       Beyoncé
# 11    12     $227,400,000                    $295,301,479     Lady Gaga
# ...
